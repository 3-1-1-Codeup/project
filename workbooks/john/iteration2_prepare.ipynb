# %% [markdown]
# - Environment Setup

# %%
import numpy as np
import pandas as pd

# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import wrangle

from wrangle import clean_311

import model

from model import split_separate_scale

pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ## Acquire and Prep

# %%
# acquire data
df = pd.read_csv('allservicecalls.csv')

# %%
df.head()
# Out:
#                Category      CASEID       OPENEDDATETIME             SLA_Date  \
# 0              Graffiti  1010444245  2012-08-15T00:00:00  2012-08-30T00:00:00
# 1  Property Maintenance  1010888252  2013-06-06T00:00:00  2013-08-09T00:00:00
# 2  Property Maintenance  1010966128  2013-07-19T00:00:00  2013-09-23T00:00:00
# 3  Property Maintenance  1011052825  2013-09-16T00:00:00  2013-09-30T00:00:00
# 4  Property Maintenance  1011052826  2013-09-16T00:00:00  2013-09-30T00:00:00
#
#   CLOSEDDATETIME Late (Yes/No)                       Dept  \
# 0            NaN           YES  Code Enforcement Services
# 1            NaN           YES  Code Enforcement Services
# 2            NaN           YES  Code Enforcement Services
# 3            NaN           YES  Code Enforcement Services
# 4            NaN           YES  Code Enforcement Services
#
#                   REASONNAME                           TYPENAME CaseStatus  \
# 0                   Graffiti           Graffiti Public Property       Open
# 1  Code Enforcement (IntExp)              Alley-Way Maintenance       Open
# 2  Code Enforcement (IntExp)   Junk Vehicle On Private Property       Open
# 3           Code Enforcement  Right Of Way/Sidewalk Obstruction       Open
# 4           Code Enforcement  Right Of Way/Sidewalk Obstruction       Open
#
#                      SourceID                              OBJECTDESC  \
# 0                  Web Portal   600  NOGALITOS ST, San Antonio, 78204
# 1                  Web Portal  6043  CASTLE QUEEN, San Antonio, 78218
# 2                  Web Portal        842  KIRK PL, San Antonio, 78226
# 3  Internal Services Requests   54  KENROCK RIDGE, San Antonio, 78254
# 4  Internal Services Requests   74  KENROCK RIDGE, San Antonio, 78254
#
#    Council District     XCOORD      YCOORD Report Starting Date  \
# 0                 5  2125683.0  13695548.0  2020-05-15T00:00:00
# 1                 2  2169702.0  13725769.0  2020-05-15T00:00:00
# 2                 5  2116192.0  13692260.0  2020-05-15T00:00:00
# 3                 7  2082242.0  13737817.0  2020-05-15T00:00:00
# 4                 7  2082389.0  13737877.0  2020-05-15T00:00:00
#
#     Report Ending Date
# 0  2021-05-15T00:00:00
# 1  2021-05-15T00:00:00
# 2  2021-05-15T00:00:00
# 3  2021-05-15T00:00:00
# 4  2021-05-15T00:00:00

# %%
df.shape
# Out:
# (495440, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495440 entries, 0 to 495439
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Category              495440 non-null  object
#  1   CASEID                495440 non-null  int64
#  2   OPENEDDATETIME        495440 non-null  object
#  3   SLA_Date              481300 non-null  object
#  4   CLOSEDDATETIME        441387 non-null  object
#  5   Late (Yes/No)         495440 non-null  object
#  6   Dept                  445141 non-null  object
#  7   REASONNAME            495440 non-null  object
#  8   TYPENAME              495440 non-null  object
#  9   CaseStatus            495440 non-null  object
#  10  SourceID              495440 non-null  object
#  11  OBJECTDESC            495440 non-null  object
#  12  Council District      495440 non-null  int64
#  13  XCOORD                495345 non-null  float64
#  14  YCOORD                495345 non-null  float64
#  15  Report Starting Date  495440 non-null  object
#  16  Report Ending Date    495440 non-null  object
# dtypes: float64(2), int64(2), object(13)
# memory usage: 64.3+ MB

# %%
df = clean_311(df)

# %%
df.head()
# Out:
#          case_id  open_date   due_date closed_date is_late  \
# 2497  1014281655 2018-02-28 2018-07-09  2020-06-06     YES
# 2498  1014281665 2018-02-28 2018-07-09  2020-06-06     YES
# 2499  1014281677 2018-02-28 2018-07-09  2020-06-06     YES
# 2556  1014300321 2018-03-06 2020-09-24  2020-05-18      NO
# 2657  1014326068 2018-03-14 2018-07-23  2020-05-27     YES
#
#                            dept call_reason  \
# 2497  Code Enforcement Services        code
# 2498  Code Enforcement Services        code
# 2499  Code Enforcement Services        code
# 2556       Development Services   buildings
# 2657  Code Enforcement Services        code
#
#                               case_type case_status  \
# 2497          Certificates of Occupancy      Closed
# 2498       Zoning: District Requirement      Closed
# 2499          Certificates of Occupancy      Closed
# 2556  Street Light Existing Res Sub Div      Closed
# 2657       Zoning: District Requirement      Closed
#
#                        source_id                                address  \
# 2497  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2498  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2499  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2556            Constituent Call     1018  KING AVE, San Antonio, 78211
# 2657  Internal Services Requests  11800  FISCHER RD, San Antonio, 78073
#
#       council_district  longitude    latitude  days_open  resolution_days_due  \
# 2497                 6  2067118.0  13723868.0      829.0                  131
# 2498                 6  2067118.0  13723868.0      829.0                  131
# 2499                 6  2067118.0  13723868.0      829.0                  131
# 2556                 4  2108015.0  13680344.0      804.0                  933
# 2657                 4  2091672.0  13658660.0      805.0                  131
#
#       days_before_or_after_due           level_of_delay  district_0  \
# 2497                    -698.0  Extremely Late Response           0
# 2498                    -698.0  Extremely Late Response           0
# 2499                    -698.0  Extremely Late Response           0
# 2556                     129.0      Very Early Response           0
# 2657                    -674.0  Extremely Late Response           0
#
#       district_1  district_2  district_3  district_4  district_5  district_6  \
# 2497           0           0           0           0           0           1
# 2498           0           0           0           0           0           1
# 2499           0           0           0           0           0           1
# 2556           0           0           0           1           0           0
# 2657           0           0           0           1           0           0
#
#       district_7  district_8  district_9  district_10 zipcode
# 2497           0           0           0            0   78251
# 2498           0           0           0            0   78251
# 2499           0           0           0            0   78251
# 2556           0           0           0            0   78211
# 2657           0           0           0            0   78073

# %%
df.shape
# Out:
# (428870, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428870 entries, 2497 to 495432
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   case_id                   428870 non-null  int64
#  1   open_date                 428870 non-null  datetime64[ns]
#  2   due_date                  428870 non-null  datetime64[ns]
#  3   closed_date               428870 non-null  datetime64[ns]
#  4   is_late                   428870 non-null  object
#  5   dept                      428870 non-null  object
#  6   call_reason               428870 non-null  object
#  7   case_type                 428870 non-null  object
#  8   case_status               428870 non-null  object
#  9   source_id                 428870 non-null  object
#  10  address                   428870 non-null  object
#  11  council_district          428870 non-null  int64
#  12  longitude                 428870 non-null  float64
#  13  latitude                  428870 non-null  float64
#  14  days_open                 428870 non-null  float64
#  15  resolution_days_due       428870 non-null  int64
#  16  days_before_or_after_due  428870 non-null  float64
#  17  level_of_delay            428870 non-null  category
#  18  district_0                428870 non-null  uint8
#  19  district_1                428870 non-null  uint8
#  20  district_2                428870 non-null  uint8
#  21  district_3                428870 non-null  uint8
#  22  district_4                428870 non-null  uint8
#  23  district_5                428870 non-null  uint8
#  24  district_6                428870 non-null  uint8
#  25  district_7                428870 non-null  uint8
#  26  district_8                428870 non-null  uint8
#  27  district_9                428870 non-null  uint8
#  28  district_10               428870 non-null  uint8
#  29  zipcode                   356715 non-null  object
# dtypes: category(1), datetime64[ns](3), float64(4), int64(3), object(8), uint8(11)
# memory usage: 67.1+ MB

# %% [markdown]
# # Extract Month, Year, and Week from open_date

# %%
df['open_month'] = df.open_date.dt.month

# %%
df['open_year'] = df.open_date.dt.year

# %%
df['open_week'] = df.open_date.dt.week

# %%
df.head()
# Out:
#          case_id  open_date   due_date closed_date is_late  \
# 2497  1014281655 2018-02-28 2018-07-09  2020-06-06     YES
# 2498  1014281665 2018-02-28 2018-07-09  2020-06-06     YES
# 2499  1014281677 2018-02-28 2018-07-09  2020-06-06     YES
# 2556  1014300321 2018-03-06 2020-09-24  2020-05-18      NO
# 2657  1014326068 2018-03-14 2018-07-23  2020-05-27     YES
#
#                            dept call_reason  \
# 2497  Code Enforcement Services        code
# 2498  Code Enforcement Services        code
# 2499  Code Enforcement Services        code
# 2556       Development Services   buildings
# 2657  Code Enforcement Services        code
#
#                               case_type case_status  \
# 2497          Certificates of Occupancy      Closed
# 2498       Zoning: District Requirement      Closed
# 2499          Certificates of Occupancy      Closed
# 2556  Street Light Existing Res Sub Div      Closed
# 2657       Zoning: District Requirement      Closed
#
#                        source_id                                address  \
# 2497  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2498  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2499  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2556            Constituent Call     1018  KING AVE, San Antonio, 78211
# 2657  Internal Services Requests  11800  FISCHER RD, San Antonio, 78073
#
#       council_district  longitude    latitude  days_open  resolution_days_due  \
# 2497                 6  2067118.0  13723868.0      829.0                  131
# 2498                 6  2067118.0  13723868.0      829.0                  131
# 2499                 6  2067118.0  13723868.0      829.0                  131
# 2556                 4  2108015.0  13680344.0      804.0                  933
# 2657                 4  2091672.0  13658660.0      805.0                  131
#
#       days_before_or_after_due           level_of_delay  district_0  \
# 2497                    -698.0  Extremely Late Response           0
# 2498                    -698.0  Extremely Late Response           0
# 2499                    -698.0  Extremely Late Response           0
# 2556                     129.0      Very Early Response           0
# 2657                    -674.0  Extremely Late Response           0
#
#       district_1  district_2  district_3  district_4  district_5  district_6  \
# 2497           0           0           0           0           0           1
# 2498           0           0           0           0           0           1
# 2499           0           0           0           0           0           1
# 2556           0           0           0           1           0           0
# 2657           0           0           0           1           0           0
#
#       district_7  district_8  district_9  district_10 zipcode  open_month  \
# 2497           0           0           0            0   78251           2
# 2498           0           0           0            0   78251           2
# 2499           0           0           0            0   78251           2
# 2556           0           0           0            0   78211           3
# 2657           0           0           0            0   78073           3
#
#       open_year  open_week
# 2497       2018          9
# 2498       2018          9
# 2499       2018          9
# 2556       2018         10
# 2657       2018         11

# %%
df.open_month.value_counts()
# Out:
# 6     43373
# 4     43219
# 3     40975
# 7     40854
# 5     40521
# 8     38110
# 9     32940
# 10    32078
# 11    30204
# 12    29048
# 1     29028
# 2     28520
# Name: open_month, dtype: int64

# %%
df.open_year.value_counts()
# Out:
# 2020    281924
# 2021    143256
# 2019      3579
# 2018       111
# Name: open_year, dtype: int64

# %%
df.open_week.value_counts()
# Out:
# 23    10405
# 15    10228
# 24    10224
# 18    10198
# 14    10156
# 12     9771
# 22     9724
# 25     9680
# 17     9675
# 16     9570
# 28     9524
# 29     9470
# 26     9469
# 32     9250
# 11     9194
# 13     9145
# 33     9138
# 30     9009
# 9      8931
# 21     8823
# 31     8822
# 10     8712
# 35     8700
# 34     8594
# 27     8547
# 36     8176
# 8      8153
# 6      7987
# 47     7702
# 38     7636
# 43     7569
# 5      7512
# 45     7459
# 37     7452
# 39     7413
# 49     7353
# 44     7343
# 42     7264
# 46     7237
# 41     7216
# 4      7083
# 1      7058
# 50     6998
# 51     6931
# 40     6852
# 3      6763
# 2      6650
# 19     6291
# 48     6131
# 20     5649
# 53     5126
# 52     5023
# 7      3884
# Name: open_week, dtype: int64

# %%
def extract_time(df):
    '''
    This function will take in a dataframe and return it with new features extracted from the open_date column
    - open_month: which month the case was opened in
    - open_year: which year the case was opened in
    - open_week: which week the case was opened in
    '''
    
    # extract month from open_date
    df['open_month'] = df.open_date.dt.month
    
    # extract year from open_date
    df['open_year'] = df.open_date.dt.year
    
    # extract week from open_date
    df['open_week'] = df.open_date.dt.week
    
    return df

# %%
# acquire data
test_df = pd.read_csv('allservicecalls.csv')

# %%
test_df.head()
# Out:
#                Category      CASEID       OPENEDDATETIME             SLA_Date  \
# 0              Graffiti  1010444245  2012-08-15T00:00:00  2012-08-30T00:00:00
# 1  Property Maintenance  1010888252  2013-06-06T00:00:00  2013-08-09T00:00:00
# 2  Property Maintenance  1010966128  2013-07-19T00:00:00  2013-09-23T00:00:00
# 3  Property Maintenance  1011052825  2013-09-16T00:00:00  2013-09-30T00:00:00
# 4  Property Maintenance  1011052826  2013-09-16T00:00:00  2013-09-30T00:00:00
#
#   CLOSEDDATETIME Late (Yes/No)                       Dept  \
# 0            NaN           YES  Code Enforcement Services
# 1            NaN           YES  Code Enforcement Services
# 2            NaN           YES  Code Enforcement Services
# 3            NaN           YES  Code Enforcement Services
# 4            NaN           YES  Code Enforcement Services
#
#                   REASONNAME                           TYPENAME CaseStatus  \
# 0                   Graffiti           Graffiti Public Property       Open
# 1  Code Enforcement (IntExp)              Alley-Way Maintenance       Open
# 2  Code Enforcement (IntExp)   Junk Vehicle On Private Property       Open
# 3           Code Enforcement  Right Of Way/Sidewalk Obstruction       Open
# 4           Code Enforcement  Right Of Way/Sidewalk Obstruction       Open
#
#                      SourceID                              OBJECTDESC  \
# 0                  Web Portal   600  NOGALITOS ST, San Antonio, 78204
# 1                  Web Portal  6043  CASTLE QUEEN, San Antonio, 78218
# 2                  Web Portal        842  KIRK PL, San Antonio, 78226
# 3  Internal Services Requests   54  KENROCK RIDGE, San Antonio, 78254
# 4  Internal Services Requests   74  KENROCK RIDGE, San Antonio, 78254
#
#    Council District     XCOORD      YCOORD Report Starting Date  \
# 0                 5  2125683.0  13695548.0  2020-05-15T00:00:00
# 1                 2  2169702.0  13725769.0  2020-05-15T00:00:00
# 2                 5  2116192.0  13692260.0  2020-05-15T00:00:00
# 3                 7  2082242.0  13737817.0  2020-05-15T00:00:00
# 4                 7  2082389.0  13737877.0  2020-05-15T00:00:00
#
#     Report Ending Date
# 0  2021-05-15T00:00:00
# 1  2021-05-15T00:00:00
# 2  2021-05-15T00:00:00
# 3  2021-05-15T00:00:00
# 4  2021-05-15T00:00:00

# %%
test_df = clean_311(test_df)

# %%
test_df.head()
# Out:
#          case_id  open_date   due_date closed_date is_late  \
# 2497  1014281655 2018-02-28 2018-07-09  2020-06-06     YES
# 2498  1014281665 2018-02-28 2018-07-09  2020-06-06     YES
# 2499  1014281677 2018-02-28 2018-07-09  2020-06-06     YES
# 2556  1014300321 2018-03-06 2020-09-24  2020-05-18      NO
# 2657  1014326068 2018-03-14 2018-07-23  2020-05-27     YES
#
#                            dept call_reason  \
# 2497  Code Enforcement Services        code
# 2498  Code Enforcement Services        code
# 2499  Code Enforcement Services        code
# 2556       Development Services   buildings
# 2657  Code Enforcement Services        code
#
#                               case_type case_status  \
# 2497          Certificates of Occupancy      Closed
# 2498       Zoning: District Requirement      Closed
# 2499          Certificates of Occupancy      Closed
# 2556  Street Light Existing Res Sub Div      Closed
# 2657       Zoning: District Requirement      Closed
#
#                        source_id                                address  \
# 2497  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2498  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2499  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2556            Constituent Call     1018  KING AVE, San Antonio, 78211
# 2657  Internal Services Requests  11800  FISCHER RD, San Antonio, 78073
#
#       council_district  longitude    latitude  days_open  resolution_days_due  \
# 2497                 6  2067118.0  13723868.0      829.0                  131
# 2498                 6  2067118.0  13723868.0      829.0                  131
# 2499                 6  2067118.0  13723868.0      829.0                  131
# 2556                 4  2108015.0  13680344.0      804.0                  933
# 2657                 4  2091672.0  13658660.0      805.0                  131
#
#       days_before_or_after_due           level_of_delay  district_0  \
# 2497                    -698.0  Extremely Late Response           0
# 2498                    -698.0  Extremely Late Response           0
# 2499                    -698.0  Extremely Late Response           0
# 2556                     129.0      Very Early Response           0
# 2657                    -674.0  Extremely Late Response           0
#
#       district_1  district_2  district_3  district_4  district_5  district_6  \
# 2497           0           0           0           0           0           1
# 2498           0           0           0           0           0           1
# 2499           0           0           0           0           0           1
# 2556           0           0           0           1           0           0
# 2657           0           0           0           1           0           0
#
#       district_7  district_8  district_9  district_10 zipcode
# 2497           0           0           0            0   78251
# 2498           0           0           0            0   78251
# 2499           0           0           0            0   78251
# 2556           0           0           0            0   78211
# 2657           0           0           0            0   78073

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428870 entries, 2497 to 495432
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   case_id                   428870 non-null  int64
#  1   open_date                 428870 non-null  datetime64[ns]
#  2   due_date                  428870 non-null  datetime64[ns]
#  3   closed_date               428870 non-null  datetime64[ns]
#  4   is_late                   428870 non-null  object
#  5   dept                      428870 non-null  object
#  6   call_reason               428870 non-null  object
#  7   case_type                 428870 non-null  object
#  8   case_status               428870 non-null  object
#  9   source_id                 428870 non-null  object
#  10  address                   428870 non-null  object
#  11  council_district          428870 non-null  int64
#  12  longitude                 428870 non-null  float64
#  13  latitude                  428870 non-null  float64
#  14  days_open                 428870 non-null  float64
#  15  resolution_days_due       428870 non-null  int64
#  16  days_before_or_after_due  428870 non-null  float64
#  17  level_of_delay            428870 non-null  category
#  18  district_0                428870 non-null  uint8
#  19  district_1                428870 non-null  uint8
#  20  district_2                428870 non-null  uint8
#  21  district_3                428870 non-null  uint8
#  22  district_4                428870 non-null  uint8
#  23  district_5                428870 non-null  uint8
#  24  district_6                428870 non-null  uint8
#  25  district_7                428870 non-null  uint8
#  26  district_8                428870 non-null  uint8
#  27  district_9                428870 non-null  uint8
#  28  district_10               428870 non-null  uint8
#  29  zipcode                   356715 non-null  object
# dtypes: category(1), datetime64[ns](3), float64(4), int64(3), object(8), uint8(11)
# memory usage: 67.1+ MB

# %%
test_df = extract_time(test_df)

# %%
test_df.head()
# Out:
#          case_id  open_date   due_date closed_date is_late  \
# 2497  1014281655 2018-02-28 2018-07-09  2020-06-06     YES
# 2498  1014281665 2018-02-28 2018-07-09  2020-06-06     YES
# 2499  1014281677 2018-02-28 2018-07-09  2020-06-06     YES
# 2556  1014300321 2018-03-06 2020-09-24  2020-05-18      NO
# 2657  1014326068 2018-03-14 2018-07-23  2020-05-27     YES
#
#                            dept call_reason  \
# 2497  Code Enforcement Services        code
# 2498  Code Enforcement Services        code
# 2499  Code Enforcement Services        code
# 2556       Development Services   buildings
# 2657  Code Enforcement Services        code
#
#                               case_type case_status  \
# 2497          Certificates of Occupancy      Closed
# 2498       Zoning: District Requirement      Closed
# 2499          Certificates of Occupancy      Closed
# 2556  Street Light Existing Res Sub Div      Closed
# 2657       Zoning: District Requirement      Closed
#
#                        source_id                                address  \
# 2497  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2498  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2499  Internal Services Requests   5550  EASTERLING, San Antonio, 78251
# 2556            Constituent Call     1018  KING AVE, San Antonio, 78211
# 2657  Internal Services Requests  11800  FISCHER RD, San Antonio, 78073
#
#       council_district  longitude    latitude  days_open  resolution_days_due  \
# 2497                 6  2067118.0  13723868.0      829.0                  131
# 2498                 6  2067118.0  13723868.0      829.0                  131
# 2499                 6  2067118.0  13723868.0      829.0                  131
# 2556                 4  2108015.0  13680344.0      804.0                  933
# 2657                 4  2091672.0  13658660.0      805.0                  131
#
#       days_before_or_after_due           level_of_delay  district_0  \
# 2497                    -698.0  Extremely Late Response           0
# 2498                    -698.0  Extremely Late Response           0
# 2499                    -698.0  Extremely Late Response           0
# 2556                     129.0      Very Early Response           0
# 2657                    -674.0  Extremely Late Response           0
#
#       district_1  district_2  district_3  district_4  district_5  district_6  \
# 2497           0           0           0           0           0           1
# 2498           0           0           0           0           0           1
# 2499           0           0           0           0           0           1
# 2556           0           0           0           1           0           0
# 2657           0           0           0           1           0           0
#
#       district_7  district_8  district_9  district_10 zipcode  open_month  \
# 2497           0           0           0            0   78251           2
# 2498           0           0           0            0   78251           2
# 2499           0           0           0            0   78251           2
# 2556           0           0           0            0   78211           3
# 2657           0           0           0            0   78073           3
#
#       open_year  open_week
# 2497       2018          9
# 2498       2018          9
# 2499       2018          9
# 2556       2018         10
# 2657       2018         11

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428870 entries, 2497 to 495432
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   case_id                   428870 non-null  int64
#  1   open_date                 428870 non-null  datetime64[ns]
#  2   due_date                  428870 non-null  datetime64[ns]
#  3   closed_date               428870 non-null  datetime64[ns]
#  4   is_late                   428870 non-null  object
#  5   dept                      428870 non-null  object
#  6   call_reason               428870 non-null  object
#  7   case_type                 428870 non-null  object
#  8   case_status               428870 non-null  object
#  9   source_id                 428870 non-null  object
#  10  address                   428870 non-null  object
#  11  council_district          428870 non-null  int64
#  12  longitude                 428870 non-null  float64
#  13  latitude                  428870 non-null  float64
#  14  days_open                 428870 non-null  float64
#  15  resolution_days_due       428870 non-null  int64
#  16  days_before_or_after_due  428870 non-null  float64
#  17  level_of_delay            428870 non-null  category
#  18  district_0                428870 non-null  uint8
#  19  district_1                428870 non-null  uint8
#  20  district_2                428870 non-null  uint8
#  21  district_3                428870 non-null  uint8
#  22  district_4                428870 non-null  uint8
#  23  district_5                428870 non-null  uint8
#  24  district_6                428870 non-null  uint8
#  25  district_7                428870 non-null  uint8
#  26  district_8                428870 non-null  uint8
#  27  district_9                428870 non-null  uint8
#  28  district_10               428870 non-null  uint8
#  29  zipcode                   356715 non-null  object
#  30  open_month                428870 non-null  int64
#  31  open_year                 428870 non-null  int64
#  32  open_week                 428870 non-null  int64
# dtypes: category(1), datetime64[ns](3), float64(4), int64(6), object(8), uint8(11)
# memory usage: 76.9+ MB

# %%
test_df.open_month.value_counts()
# Out:
# 6     43373
# 4     43219
# 3     40975
# 7     40854
# 5     40521
# 8     38110
# 9     32940
# 10    32078
# 11    30204
# 12    29048
# 1     29028
# 2     28520
# Name: open_month, dtype: int64

# %%
test_df.open_year.value_counts()
# Out:
# 2020    281924
# 2021    143256
# 2019      3579
# 2018       111
# Name: open_year, dtype: int64

# %%
test_df.open_week.value_counts()
# Out:
# 23    10405
# 15    10228
# 24    10224
# 18    10198
# 14    10156
# 12     9771
# 22     9724
# 25     9680
# 17     9675
# 16     9570
# 28     9524
# 29     9470
# 26     9469
# 32     9250
# 11     9194
# 13     9145
# 33     9138
# 30     9009
# 9      8931
# 21     8823
# 31     8822
# 10     8712
# 35     8700
# 34     8594
# 27     8547
# 36     8176
# 8      8153
# 6      7987
# 47     7702
# 38     7636
# 43     7569
# 5      7512
# 45     7459
# 37     7452
# 39     7413
# 49     7353
# 44     7343
# 42     7264
# 46     7237
# 41     7216
# 4      7083
# 1      7058
# 50     6998
# 51     6931
# 40     6852
# 3      6763
# 2      6650
# 19     6291
# 48     6131
# 20     5649
# 53     5126
# 52     5023
# 7      3884
# Name: open_week, dtype: int64
