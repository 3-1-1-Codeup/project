# %%
import pandas as pd
import numpy as np
import os

# %%
def get_311_data():
    '''
    This function uses pandas read .csv to read in the downloaded .csv 
    from: https://data.sanantonio.gov/dataset/service-calls/resource/20eb6d22-7eac-425a-85c1-fdb365fd3cd7
    after the .csv is read in, it returns it as a data frame.
    '''
    df= pd.read_csv('allservicecalls.csv', index_col=0)
    return df

# %%
df= get_311_data()

# %%
df.head()
# Out:
#                           CASEID OPENEDDATETIME   SLA_Date CLOSEDDATETIME  \
# Category
# Graffiti              1010444245      8/15/2012  8/30/2012            NaN
# Property Maintenance  1010888252       6/6/2013   8/9/2013            NaN
# Property Maintenance  1010966128      7/19/2013  9/23/2013            NaN
# Property Maintenance  1011052825      9/16/2013  9/30/2013            NaN
# Property Maintenance  1011052826      9/16/2013  9/30/2013            NaN
#
#                      Late (Yes/No)                       Dept  \
# Category
# Graffiti                       YES  Code Enforcement Services
# Property Maintenance           YES  Code Enforcement Services
# Property Maintenance           YES  Code Enforcement Services
# Property Maintenance           YES  Code Enforcement Services
# Property Maintenance           YES  Code Enforcement Services
#
#                                      REASONNAME  \
# Category
# Graffiti                               Graffiti
# Property Maintenance  Code Enforcement (IntExp)
# Property Maintenance  Code Enforcement (IntExp)
# Property Maintenance           Code Enforcement
# Property Maintenance           Code Enforcement
#
#                                                TYPENAME CaseStatus  \
# Category
# Graffiti                       Graffiti Public Property       Open
# Property Maintenance              Alley-Way Maintenance       Open
# Property Maintenance   Junk Vehicle On Private Property       Open
# Property Maintenance  Right Of Way/Sidewalk Obstruction       Open
# Property Maintenance  Right Of Way/Sidewalk Obstruction       Open
#
#                                         SourceID  \
# Category
# Graffiti                              Web Portal
# Property Maintenance                  Web Portal
# Property Maintenance                  Web Portal
# Property Maintenance  Internal Services Requests
# Property Maintenance  Internal Services Requests
#
#                                                   OBJECTDESC  \
# Category
# Graffiti               600  NOGALITOS ST, San Antonio, 78204
# Property Maintenance  6043  CASTLE QUEEN, San Antonio, 78218
# Property Maintenance        842  KIRK PL, San Antonio, 78226
# Property Maintenance   54  KENROCK RIDGE, San Antonio, 78254
# Property Maintenance   74  KENROCK RIDGE, San Antonio, 78254
#
#                       Council District     XCOORD      YCOORD  \
# Category
# Graffiti                             5  2125683.0  13695548.0
# Property Maintenance                 2  2169702.0  13725769.0
# Property Maintenance                 5  2116192.0  13692260.0
# Property Maintenance                 7  2082242.0  13737817.0
# Property Maintenance                 7  2082389.0  13737877.0
#
#                      Report Starting Date Report Ending Date
# Category
# Graffiti                        5/15/2020          5/15/2021
# Property Maintenance            5/15/2020          5/15/2021
# Property Maintenance            5/15/2020          5/15/2021
# Property Maintenance            5/15/2020          5/15/2021
# Property Maintenance            5/15/2020          5/15/2021

# %%
df.REASONNAME.value_counts()
# Out:
# Waste Collection                 152898
# Code Enforcement                 136050
# Field Operations                  75100
# Miscellaneous                     30407
# Traffic Operations                26148
# Streets                           25816
# Trades                             9590
# Stormwater                         6797
# Small Business                     6106
# Solid Waste                        5261
# Workforce Development              5250
# Customer Service                   4650
# 311 Call Center                    4196
# Food Establishments                1610
# Land Development                   1094
# Facility License                    908
# Clean and Green                     758
# Dangerous Premise                   701
# Shops (Internal)                    385
# Vector                              243
# Historic Preservation               224
# Signals                             223
# Urban Forestry                      209
# Traffic Engineering Design          206
# Graffiti (IntExp)                   112
# Engineering Division                108
# Natural Resources                    84
# General Sanitation                   66
# Code Enforcement (Internal)          58
# Code Enforcement (IntExp)            45
# Park Projects                        37
# Storm Water                          28
# Signs and Markings                   22
# Tree Crew                            14
# Director's Office Horizontal         10
# Graffiti                             10
# Brush                                 9
# Storm Water Engineering               3
# District 2                            1
# Shops                                 1
# Clean and Green Natural Areas         1
# Traffic Issue Investigation           1
# Name: REASONNAME, dtype: int64
